# %% [markdown]
# #### Install VScode
# (Python in VScode)
# - https://code.visualstudio.com/docs/languages/python
#
# 1. install VScode
# 2. install python code extension inside VS code (a pop up will appear)
#
# - Quick start:
# - Step 1. Install a supported version of Python on your system (note: that the system install of Python on macOS is not supported).
# - Step 2. Install the Python extension for Visual Studio Code.
# - Step 3. Open or create a Python file and start coding!

# %% [markdown]
# #### Create a folder with a new name :
# - on that folder - right click - more options - open with VScode.
#
#   OR
#
# - open on VScode - manually
#     - open fresh window of VScode
#       ![Screenshot 2024-12-18 at 1.00.11 PM.png](data:image/png;base64,...)

# %% [markdown]
# File -> Open folder
# ![Screenshot 2024-12-18 at 1.07.20 PM.png](data:image/png;base64,...)

# %% [markdown]
# Create a .py file inside the folder -
#
# From left panel - select the create `new file option` available beside the folder name.
#
# - name the file as `file_name.py`
#
# ![Screenshot 2024-12-18 at 1.17.03 PM.png](data:image/png;base64,...)

# %% [markdown]
# Connect this terminal with Anaconda -
# - need to select the same interpreter that is present inside the anaconda.
#   - need to select the `python interpreter`
#   - View -> Command pallete -> Python :  Select Interpreter
#
#   ![Screenshot 2024-12-18 at 1.36.00 PM.png](data:image/png;base64,...)

# %% [markdown]
# If not finding the python interreter in command pallete
# - in the left hand side there is an search option
# - select that option
# - write python
#   - will get python extension
#   - install the python extenson (if not installed previously) - then the option will appear post installation.
#
# ![Screenshot 2024-12-18 at 1.38.14 PM.png](data:image/png;base64,...)

# %% [markdown]
# - Create a virtual environment inside VScode :
# 1. Open Terminal
# 2. From `bash` change it to :
#   -  For windows  -  from right hand side - select `cmd`
#   -  For mac - select `zsh`
#
# ![Screenshot 2024-12-18 at 1.19.33 PM.png](data:image/png;base64,...)

# %% [markdown]
# To install Anaconda in the local system
# - download anaconda - (for different OS)
# ![Screenshot 2024-12-18 at 1.50.23 PM.png](data:image/png;base64,...)

# %% [markdown]
# Inside command pallate will get two interpreters:
# 1. base interpreter - select the base interpreter
# 2. python interpreter
#
#
# ![Screenshot 2024-12-18 at 1.54.04 PM.png](data:image/png;base64,...)

# %% [markdown]
# #### Restart the terminal

# %% [markdown]
# #### Create virtual environment -
# conda create -p venv python=3.8
# - to create the python environment in the same folder `-p` is used
#
# proceed `y`
#
# ![Screenshot 2024-12-18 at 2.02.18 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-12-18 at 2.07.20 PM.png](data:image/png;base64,...)

# %% [markdown]
# After creating the virtual environment - need to activate it.
# - write click on (venv) - copy the path
# ![Screenshot 2024-12-18 at 2.09.47 PM.png](data:image/png;base64,...)

# %% [markdown]
# Command take it from terminal -
#
# ![Screenshot 2024-12-18 at 2.13.47 PM.png](data:image/png;base64,...)

# %% [markdown]
# To check files and folders -
#
# - pip list
#
# ![Screenshot 2024-12-18 at 2.15.16 PM.png](data:image/png;base64,...)
